# %%
print("Hola NovaMarket")
print("Python está funcionando")
# Out:
# Hola NovaMarket
# Python está funcionando

# %%
# Variables
empresa       = "NovaMarket Tech"
ventas_total  = 1169270.5
registros     = 500
leticia_pierde = True

print(empresa)
print(ventas_total)
print(registros)
print(leticia_pierde)
# Out:
# NovaMarket Tech
# 1169270.5
# 500
# True

# %%
texto    = "Bogotá"
decimal  = 1650.00
entero   = 500
booleano = True

print(type(texto))
print(type(decimal))
print(type(entero))
print(type(booleano))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'int'>
# <class 'bool'>

# %%
ciudad   = "Leticia"
utilidad = -79342.0

print(f"Ciudad: {ciudad}")
print(f"Utilidad de {ciudad}: ${utilidad:,.2f}")
print(f"¿Pierde dinero? {utilidad < 0}")
# Out:
# Ciudad: Leticia
# Utilidad de Leticia: $-79,342.00
# ¿Pierde dinero? True

# %%
import pandas as pd
import numpy as np

print("pandas versión:", pd.__version__)
print("numpy versión:", np.__version__)
print("✅ Herramientas listas")
# Out:
# pandas versión: 2.2.2
# numpy versión: 2.0.2
# ✅ Herramientas listas

# %%
df = pd.read_csv("/content/S01_Ventas_Novamarket_Datos_Sucios.csv", parse_dates=["Fecha"])
df.head()
# Out:
#    ID_Transaccion      Fecha          Producto    Categoria        Ciudad  \
# 0            1099 2023-10-02    Laptop Gamer Z      Laptops      Medellín
# 1            1567 2023-11-24    Laptop Gamer Z      Laptops          Cali
# 2            1018 2023-10-23  Smartphone Pro X  Smartphones       Leticia
# 3            1249 2023-09-13      Smartwatch Q    Wearables  Barranquilla
# 4            1492 2023-09-30      Smartwatch Q    Wearables          Cali
#
#    Cantidad  Precio_Unitario  Costo_Unitario  Descuento_pct  Costo_Envio
# 0       2.0             2500            1800            0.2          180
# 1       2.0             2500            1800            0.6          200
# 2       4.0              800             550            0.0         1650
# 3       3.0              300             180            0.0          220
# 4       3.0              300             180            0.0          200

# %%
print("Forma del DataFrame:", df.shape)
print("Filas:   ", df.shape[0])
print("Columnas:", df.shape[1])
# Out:
# Forma del DataFrame: (662, 10)
# Filas:    662
# Columnas: 10

# %%
df.describe().round(2)
# Out:
#        ID_Transaccion                          Fecha  Cantidad  \
# count          662.00                            662    656.00
# mean          1324.20  2023-10-25 06:22:50.392749312      2.59
# min           1001.00            2023-09-01 00:00:00      1.00
# 25%           1163.25            2023-10-01 00:00:00      2.00
# 50%           1323.50            2023-10-30 00:00:00      3.00
# 75%           1485.75            2023-11-24 00:00:00      4.00
# max           1650.00            2023-11-30 00:00:00      4.00
# std            187.51                            NaN      1.10
#
#        Precio_Unitario  Costo_Unitario  Descuento_pct  Costo_Envio
# count           662.00          662.00         662.00       662.00
# mean            955.66          652.15           0.16       347.04
# min             300.00          180.00           0.00       150.00
# 25%             300.00          180.00           0.00       157.50
# ...

# %%
# Desafío 1 — 10 primeras filas
df.head(10)
# Out:
#    ID_Transaccion      Fecha             Producto    Categoria        Ciudad  \
# 0            1099 2023-10-02       Laptop Gamer Z      Laptops      Medellín
# 1            1567 2023-11-24       Laptop Gamer Z      Laptops          Cali
# 2            1018 2023-10-23     Smartphone Pro X  Smartphones       Leticia
# 3            1249 2023-09-13         Smartwatch Q    Wearables  Barranquilla
# 4            1492 2023-09-30         Smartwatch Q    Wearables          Cali
# 5            1649 2023-11-24     Smartphone Pro X  Smartphones        BOGOTÁ
# 6            1233 2023-10-08     Smartphone Pro X  Smartphones        Bogotá
# 7            1441 2023-09-15       Laptop Gamer Z      Laptops        Bogotá
# 8            1436 2023-11-29  Audifonos Bluetooth        Audio  Barranquilla
# 9            1209 2023-11-15  Audifonos Bluetooth        Audio        Bogotá
#
#    Cantidad  Precio_Unitario  Costo_Unitario  Descuento_pct  Costo_Envio
# ...

# %%
# Desafío 2 — estadísticas solo de Costo_Envio
df['Costo_Envio'].describe().round(2)
# Out:
# count     662.00
# mean      347.04
# std       449.55
# min       150.00
# 25%       157.50
# 50%       200.00
# 75%       220.00
# max      1650.00
# Name: Costo_Envio, dtype: float64
